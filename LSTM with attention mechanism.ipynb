# %%
import pandas as pd
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_price = pd.read_excel("data/Day-ahead_prices.xlsx")
df_price = df_price.drop(index=range(0, 8))
df_price = df_price.reset_index(drop=True)
new_header = df_price.iloc[0]
df_price = df_price[1:]
df_price.columns = new_header 
df_price.tail()
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 0                 Start date               End date  \
# 44996   Feb 17, 2025 7:00 PM   Feb 17, 2025 8:00 PM
# 44997   Feb 17, 2025 8:00 PM   Feb 17, 2025 9:00 PM
# 44998   Feb 17, 2025 9:00 PM  Feb 17, 2025 10:00 PM
# 44999  Feb 17, 2025 10:00 PM  Feb 17, 2025 11:00 PM
# 45000  Feb 17, 2025 11:00 PM  Feb 18, 2025 12:00 AM
#
# 0     Germany/Luxembourg [€/MWh] ∅ DE/LU neighbours [€/MWh] Belgium [€/MWh]  \
# 44996                     215.36                     207.55          215.46
# 44997                     177.86                     173.17          177.95
# 44998                     155.19                      152.2          155.38
# 44999                     139.39                     137.86          139.51
# 45000                     129.57                     129.34             130
#
# 0     Denmark 1 [€/MWh] Denmark 2 [€/MWh] France [€/MWh] Netherlands [€/MWh]  \
# 44996            215.36             215.4         215.52              215.43
# 44997            177.86            177.88            178              177.93
# 44998            155.19             155.2         155.62               155.3
# 44999            139.39             139.4            140              139.39
# 45000            129.57            129.56          130.6              129.72
#
# 0     Norway 2 [€/MWh] Austria [€/MWh] Poland [€/MWh] Sweden 4 [€/MWh]  \
# 44996           136.41          216.13          218.2           215.27
# 44997           125.63          178.69          180.9           179.55
# 44998           116.26          159.84         154.09           155.93
# 44999           107.73          150.02         137.24           136.05
# 45000           111.25          134.93         127.68           126.77
#
# 0     Switzerland [€/MWh] Czech Republic [€/MWh] DE/AT/LU [€/MWh]  \
# 44996              203.38                  216.5                -
# 44997              171.35                 179.08                -
# 44998              159.98                  151.4                -
# 44999              156.48                 131.21                -
# 45000              149.67                 122.95                -
#
# 0     Northern Italy [€/MWh] Slovenia [€/MWh] Hungary [€/MWh]
# 44996                 215.52           216.46          216.88
# 44997                    178           179.03          179.49
# 44998                    160           161.59          166.68
# 44999                 153.72           153.72          164.94
# 45000                 147.26           140.81          149.69

# %%
df_consum = pd.read_excel("data/Actual_consumption.xlsx")
df_consum = df_consum.drop(index=range(0, 8))
df_consum = df_consum.reset_index(drop=True)
new_header = df_consum.iloc[0]
df_consum = df_consum[1:]
df_consum.columns = new_header
df_consum.head()
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# 0            Start date             End date grid load [MWh]  \
# 1  Jan 1, 2020 12:00 AM  Jan 1, 2020 1:00 AM         43968.5
# 2   Jan 1, 2020 1:00 AM  Jan 1, 2020 2:00 AM           43047
# 3   Jan 1, 2020 2:00 AM  Jan 1, 2020 3:00 AM           41895
# 4   Jan 1, 2020 3:00 AM  Jan 1, 2020 4:00 AM        40701.75
# 5   Jan 1, 2020 4:00 AM  Jan 1, 2020 5:00 AM        40681.25
#
# 0 Grid load incl. hydro pumped storage [MWh] Hydro pumped storage [MWh]  \
# 1                                   44244.25                     275.75
# 2                                   43528.75                     481.75
# 3                                    42576.5                      681.5
# 4                                      41453                     751.25
# 5                                   42153.25                       1472
#
# 0 Residual load [MWh]
# 1            37334.25
# 2               35991
# 3               34458
# 4               33152
# 5            32930.75

# %%
df_consum.drop(columns={'Hydro pumped storage [MWh]'},inplace=True)

# %%
df_consum.tail()
# Out:
# 0                 Start date               End date grid load [MWh]  \
# 44996   Feb 17, 2025 7:00 PM   Feb 17, 2025 8:00 PM        69697.25
# 44997   Feb 17, 2025 8:00 PM   Feb 17, 2025 9:00 PM         66565.5
# 44998   Feb 17, 2025 9:00 PM  Feb 17, 2025 10:00 PM        63781.25
# 44999  Feb 17, 2025 10:00 PM  Feb 17, 2025 11:00 PM         61239.5
# 45000  Feb 17, 2025 11:00 PM  Feb 18, 2025 12:00 AM        58464.25
#
# 0     Grid load incl. hydro pumped storage [MWh] Residual load [MWh]
# 44996                                    69702.5               63404
# 44997                                      66592               60146
# 44998                                    63789.5            57530.25
# 44999                                   61308.25            55342.25
# 45000                                    58632.5            52697.75

# %%
def convert_to_float(x):
    try:
        return float(x)
    except ValueError:
        return np.nan
    
columns_to_convert = ['grid load [MWh]', 'Residual load [MWh]']
for col in columns_to_convert:
    df_consum[col] = df_consum[col].apply(convert_to_float)

# %%
df_generate = pd.read_excel("data/Actual_generation.xlsx")
df_generate = df_generate.drop(index=range(0, 8))
df_generate = df_generate.reset_index(drop=True)
new_header = df_generate.iloc[0]
df_generate = df_generate[1:]
df_generate.columns = new_header
# Out:
# C:\Users\asus\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
columns_to_convert = ['Biomass [MWh]','Hydropower [MWh]','Wind offshore [MWh]','Wind onshore [MWh]','Photovoltaics [MWh]','Other renewable [MWh]','Nuclear [MWh]','Lignite [MWh]','Hard coal [MWh]','Fossil gas [MWh]','Hydro pumped storage [MWh]','Other conventional [MWh]']
for col in columns_to_convert:
    df_generate[col] = df_generate[col].apply(convert_to_float)

# %%
df_generate.tail(24)
# Out:
# 0                 Start date               End date  Biomass [MWh]  \
# 44977  Feb 17, 2025 12:00 AM   Feb 17, 2025 1:00 AM        4289.25
# 44978   Feb 17, 2025 1:00 AM   Feb 17, 2025 2:00 AM        4276.50
# 44979   Feb 17, 2025 2:00 AM   Feb 17, 2025 3:00 AM        4264.00
# 44980   Feb 17, 2025 3:00 AM   Feb 17, 2025 4:00 AM        4211.00
# 44981   Feb 17, 2025 4:00 AM   Feb 17, 2025 5:00 AM        4209.50
# 44982   Feb 17, 2025 5:00 AM   Feb 17, 2025 6:00 AM        4185.25
# 44983   Feb 17, 2025 6:00 AM   Feb 17, 2025 7:00 AM        4176.25
# 44984   Feb 17, 2025 7:00 AM   Feb 17, 2025 8:00 AM        4198.75
# 44985   Feb 17, 2025 8:00 AM   Feb 17, 2025 9:00 AM        4239.50
# 44986   Feb 17, 2025 9:00 AM  Feb 17, 2025 10:00 AM        4237.25
# 44987  Feb 17, 2025 10:00 AM  Feb 17, 2025 11:00 AM        4225.00
# 44988  Feb 17, 2025 11:00 AM  Feb 17, 2025 12:00 PM        4212.50
# 44989  Feb 17, 2025 12:00 PM   Feb 17, 2025 1:00 PM        4219.25
# 44990   Feb 17, 2025 1:00 PM   Feb 17, 2025 2:00 PM        4240.75
# 44991   Feb 17, 2025 2:00 PM   Feb 17, 2025 3:00 PM        4251.75
# 44992   Feb 17, 2025 3:00 PM   Feb 17, 2025 4:00 PM        4267.75
# 44993   Feb 17, 2025 4:00 PM   Feb 17, 2025 5:00 PM        4307.75
# 44994   Feb 17, 2025 5:00 PM   Feb 17, 2025 6:00 PM        4317.25
# 44995   Feb 17, 2025 6:00 PM   Feb 17, 2025 7:00 PM        4336.50
# 44996   Feb 17, 2025 7:00 PM   Feb 17, 2025 8:00 PM        4329.25
# 44997   Feb 17, 2025 8:00 PM   Feb 17, 2025 9:00 PM        4333.50
# 44998   Feb 17, 2025 9:00 PM  Feb 17, 2025 10:00 PM        4326.50
# 44999  Feb 17, 2025 10:00 PM  Feb 17, 2025 11:00 PM        4321.00
# 45000  Feb 17, 2025 11:00 PM  Feb 18, 2025 12:00 AM        4319.00
#
# 0      Hydropower [MWh]  Wind offshore [MWh]  Wind onshore [MWh]  \
# 44977           1218.75               883.25             7221.00
# 44978           1219.50               615.25             6920.50
# 44979           1206.25               459.00             6327.00
# 44980           1196.25               309.00             5993.25
# 44981           1200.50               357.75             5763.00
# 44982           1196.75               494.75             5674.00
# 44983           1330.75               640.75             5804.50
# 44984           1721.00               689.50             5550.75
# 44985           1565.50               762.75             4784.00
# 44986           1355.50               795.75             2917.50
# 44987           1197.50               830.75             1669.75
# 44988           1208.75               705.50             1401.75
# 44989           1204.50               639.00             1204.00
# 44990           1227.00               711.75             1120.75
# 44991           1279.25               814.50             1253.25
# 44992           1290.50               827.50             1605.25
# 44993           1640.00               939.50             2002.50
# 44994           1656.75               991.25             2905.75
# 44995           1567.00              1144.25             4300.00
# 44996           1620.25              1124.00             5165.25
# 44997           1439.75              1018.00             5401.50
# 44998           1310.75               966.25             5284.75
# 44999           1323.75               932.25             4965.00
# 45000           1417.00              1049.50             4717.00
#
# 0      Photovoltaics [MWh]  Other renewable [MWh]  Nuclear [MWh]  \
# 44977                 0.00                 113.00            NaN
# 44978                 0.00                 113.00            NaN
# 44979                 0.00                 113.00            NaN
# 44980                 0.00                 113.00            NaN
# 44981                 0.00                 113.00            NaN
# 44982                 0.00                 117.50            NaN
# 44983                 0.00                 119.00            NaN
# 44984               456.25                 119.00            NaN
# 44985              5596.00                 115.50            NaN
# 44986             14742.50                 112.00            NaN
# 44987             23669.25                 112.00            NaN
# 44988             29253.25                 112.00            NaN
# 44989             30745.75                 110.50            NaN
# 44990             29262.50                 107.75            NaN
# 44991             24960.50                 112.00            NaN
# 44992             17450.00                 112.00            NaN
# 44993              7521.75                 112.00            NaN
# 44994               653.25                 112.00            NaN
# 44995                 5.25                 112.00            NaN
# 44996                 4.00                 112.00            NaN
# 44997                 0.00                 112.00            NaN
# 44998                 0.00                 112.00            NaN
# 44999                 0.00                 112.00            NaN
# 45000                 0.00                 112.00            NaN
#
# 0      Lignite [MWh]  Hard coal [MWh]  Fossil gas [MWh]  \
# 44977       10626.00          8033.25          10813.50
# 44978       10621.00          7980.00          10629.75
# 44979       10610.75          7967.25          10962.00
# 44980       10600.00          7949.75          11476.75
# 44981       10604.00          8017.00          12361.00
# 44982       10820.00          8063.50          14722.75
# 44983       11026.00          7885.25          16852.75
# 44984       10996.00          7840.00          17632.75
# 44985       11280.75          7868.25          17858.00
# 44986       11624.25          7873.25          16213.50
# 44987       11753.75          7791.50          14709.25
# 44988       11893.75          7164.75          12073.25
# 44989       11344.25          6632.25          11366.50
# 44990       11466.75          6419.75          11274.50
# 44991       11741.75          6556.25          11392.00
# 44992       12178.75          7395.25          12847.00
# 44993       12524.00          7626.50          17084.50
# 44994       12846.75          7921.50          18458.25
# 44995       12967.50          8207.75          18802.00
# 44996       12988.00          8210.50          18307.50
# 44997       12908.75          8176.50          17179.25
# 44998       12630.25          8152.25          16639.25
# 44999       12607.00          8135.75          16241.00
# 45000       12421.50          8116.00          15021.50
#
# 0      Hydro pumped storage [MWh]  Other conventional [MWh]
# 44977                       29.25                   1474.50
# 44978                       19.25                   1467.75
# 44979                       22.50                   1465.00
# 44980                        4.50                   1469.50
# 44981                       34.50                   1467.25
# 44982                      135.25                   1462.25
# 44983                     2102.75                   1458.25
# 44984                     5914.50                   1602.00
# 44985                     5679.75                   1588.50
# 44986                     2600.50                   1447.25
# 44987                      484.00                   1437.50
# 44988                      238.00                   1427.00
# 44989                        2.50                   1424.00
# 44990                       11.50                   1432.25
# 44991                       34.25                   1419.00
# 44992                      203.75                   1434.00
# 44993                     2253.75                   1429.75
# 44994                     5017.00                   1550.25
# 44995                     5601.75                   1653.25
# 44996                     5144.75                   1514.50
# 44997                     3989.75                   1425.50
# 44998                     2152.00                   1418.50
# 44999                      736.00                   1413.25
# 45000                      199.50                   1418.75

# %%
new_cols = ['Biomass [MWh]','Hydropower [MWh]','Other renewable [MWh]','Nuclear [MWh]','Lignite [MWh]','Hard coal [MWh]','Fossil gas [MWh]','Hydro pumped storage [MWh]','Other conventional [MWh]']
df_generate['Other Generation'] = df_generate.drop(columns=['Start date', 'End date'])[new_cols].sum(axis=1)
df_generate['Other Generation'] = df_generate.drop(columns=['Start date', 'End date'])[new_cols].sum(axis=1)

# %%
df_generation = df_generate[['Start date', 'End date', 'Other Generation', 'Wind offshore [MWh]','Wind onshore [MWh]','Photovoltaics [MWh]']]

# %%
df_merge = pd.merge(df_consum,df_price[['Start date','Germany/Luxembourg [€/MWh]']],on = 'Start date')
df = pd.merge(df_generation,df_merge[['Start date','Germany/Luxembourg [€/MWh]','grid load [MWh]','Residual load [MWh]']],on = 'Start date')
df = df.rename(columns={'grid load [MWh]': 'Total Grid','Germany/Luxembourg [€/MWh]':'Germany Prices','Residual load [MWh]':'Residual Load','Wind offshore [MWh]':'Wind offshore','Wind onshore [MWh]':'Wind onshore','Photovoltaics [MWh]':'Photovoltaics'})
df['Start date'] = pd.to_datetime(df['Start date'])
df["Year"] = pd.to_datetime(df["Start date"]).dt.year
df['Date'] = pd.to_datetime(df['Start date'], format='%Y-%m-%d',errors='coerce').dt.date
df['Time'] = pd.to_datetime(df['Start date'],format='%H:%M:%S').dt.time
df["Month"] = pd.to_datetime(df["Start date"]).dt.month
df["Day"] = pd.to_datetime(df["Start date"]).dt.day_name()
war_start_date = pd.Timestamp("2022-02-24")
df["War Indicator"] = (df["Start date"] >= war_start_date).astype(int)
df.drop(columns={'End date'},inplace=True)
df.set_index('Start date',inplace=True)
df.index = pd.to_datetime(df.index, errors='coerce')
df['Germany Prices'] = pd.to_numeric(df['Germany Prices'], errors='coerce')
df.head(5)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8904\1819096435.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Start date'] = pd.to_datetime(df['Start date'])
# 0                    Other Generation  Wind offshore  Wind onshore  \
# Start date
# 2020-01-01 00:00:00          34496.75         549.25       6085.00
# 2020-01-01 01:00:00          33937.75        1169.25       5886.75
# 2020-01-01 02:00:00          35350.00        1665.50       5771.50
# 2020-01-01 03:00:00          35671.50        2062.25       5487.50
# 2020-01-01 04:00:00          35358.00        2292.00       5458.50
#
# 0                    Photovoltaics  Germany Prices  Total Grid  Residual Load  \
# Start date
# 2020-01-01 00:00:00            0.0           41.88    43968.50       37334.25
# 2020-01-01 01:00:00            0.0           38.60    43047.00       35991.00
# 2020-01-01 02:00:00            0.0           36.55    41895.00       34458.00
# 2020-01-01 03:00:00            0.0           32.32    40701.75       33152.00
# 2020-01-01 04:00:00            0.0           30.85    40681.25       32930.75
#
# 0                    Year        Date      Time  Month        Day  \
# Start date
# 2020-01-01 00:00:00  2020  2020-01-01  00:00:00      1  Wednesday
# 2020-01-01 01:00:00  2020  2020-01-01  01:00:00      1  Wednesday
# 2020-01-01 02:00:00  2020  2020-01-01  02:00:00      1  Wednesday
# 2020-01-01 03:00:00  2020  2020-01-01  03:00:00      1  Wednesday
# 2020-01-01 04:00:00  2020  2020-01-01  04:00:00      1  Wednesday
#
# 0                    War Indicator
# Start date
# 2020-01-01 00:00:00              0
# 2020-01-01 01:00:00              0
# 2020-01-01 02:00:00              0
# 2020-01-01 03:00:00              0
# 2020-01-01 04:00:00              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 45030 entries, 2020-01-01 00:00:00 to 2025-02-17 23:00:00
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Other Generation  45030 non-null  float64
#  1   Wind offshore     45030 non-null  float64
#  2   Wind onshore      45030 non-null  float64
#  3   Photovoltaics     45030 non-null  float64
#  4   Germany Prices    45030 non-null  float64
#  5   Total Grid        45030 non-null  float64
#  6   Residual Load     45030 non-null  float64
#  7   Year              45030 non-null  int32
#  8   Date              45030 non-null  object
#  9   Time              45030 non-null  object
#  10  Month             45030 non-null  int32
#  11  Day               45030 non-null  object
#  12  War Indicator     45030 non-null  int32
# dtypes: float64(7), int32(3), object(3)
# memory usage: 4.3+ MB

# %%
duplicates = df.index.duplicated()
print(df.index[duplicates])
df = df[~df.index.duplicated(keep='first')]
# Out:
# DatetimeIndex(['2020-10-25 02:00:00', '2020-10-25 02:00:00',
#                '2020-10-25 02:00:00', '2020-10-25 02:00:00',
#                '2020-10-25 02:00:00', '2020-10-25 02:00:00',
#                '2020-10-25 02:00:00', '2021-10-31 02:00:00',
#                '2021-10-31 02:00:00', '2021-10-31 02:00:00',
#                '2021-10-31 02:00:00', '2021-10-31 02:00:00',
#                '2021-10-31 02:00:00', '2021-10-31 02:00:00',
#                '2022-10-30 02:00:00', '2022-10-30 02:00:00',
#                '2022-10-30 02:00:00', '2022-10-30 02:00:00',
#                '2022-10-30 02:00:00', '2022-10-30 02:00:00',
#                '2022-10-30 02:00:00', '2023-10-29 02:00:00',
#                '2023-10-29 02:00:00', '2023-10-29 02:00:00',
#                '2023-10-29 02:00:00', '2023-10-29 02:00:00',
#                '2023-10-29 02:00:00', '2023-10-29 02:00:00',
#                '2024-10-27 02:00:00', '2024-10-27 02:00:00',
#                '2024-10-27 02:00:00', '2024-10-27 02:00:00',
#                '2024-10-27 02:00:00', '2024-10-27 02:00:00',
#                '2024-10-27 02:00:00'],
#               dtype='datetime64[ns]', name='Start date', freq=None)

# %%
df.isna().sum()
# Out:
# 0
# Other Generation    0
# Wind offshore       0
# Wind onshore        0
# Photovoltaics       0
# Germany Prices      0
# Total Grid          0
# Residual Load       0
# Year                0
# Date                0
# Time                0
# Month               0
# Day                 0
# War Indicator       0
# dtype: int64

# %%
columns_na = ['Total Grid', 'Residual Load', 'Other Generation','Wind onshore','Wind offshore','Photovoltaics','Germany Prices']
df[columns_na] = df[columns_na].apply(lambda col: col.fillna(col.mean()))

# %%
sns.distplot(df["Germany Prices"])
plt.title("Prices Distribution")
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8904\3591029626.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Germany Prices"])
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Prices Distribution')

# %%
fig, ax = plt.subplots(3,3,figsize=(12,12))
fig.subplots_adjust(wspace=0.25, hspace=0.25)

ax[0][0].boxplot(df['Other Generation'])
ax[0][0].set_title('Other Generation ')

ax[0][1].boxplot(df['Germany Prices'])
ax[0][1].set_title('Germany Prices')

ax[0][2].boxplot(df['Total Grid'])
ax[0][2].set_title('Total Grid ')

ax[1][0].boxplot(df['Residual Load'])
ax[1][0].set_title('Residual Load')

ax[1][1].boxplot(df['Wind onshore'])
ax[1][1].set_title('Wind onshore')

ax[1][2].boxplot(df['Wind offshore'])
ax[1][2].set_title('Wind offshore')

ax[2][0].boxplot(df['Photovoltaics'])
ax[2][0].set_title('Photovoltaics')
# Out:
# Text(0.5, 1.0, 'Photovoltaics')

# %%
df.drop(columns=['Day','Date','Month','Time','Year'],inplace = True)

# %%
for i in df.columns:    
    dt = df[i].astype(float).to_numpy()
    Q1=np.percentile(dt,25)
    Q3=np.percentile(dt,75)
    IQ=Q3-Q1
    upper=Q3+1.5*IQ
    lower=Q1-1.5*IQ

    dt[(dt[:]>upper) | (dt[:]<lower)]=np.nan
    df[i]=dt

# %%
df.isnull().sum()
# Out:
# 0
# Other Generation      81
# Wind offshore          0
# Wind onshore         906
# Photovoltaics       3706
# Germany Prices      3465
# Total Grid             0
# Residual Load         57
# War Indicator          0
# dtype: int64

# %%
# Filling the outliers using interpolation method
df=df.interpolate(method='linear', axis=0)
df.isna().sum()
# Out:
# 0
# Other Generation    0
# Wind offshore       0
# Wind onshore        0
# Photovoltaics       0
# Germany Prices      0
# Total Grid          0
# Residual Load       0
# War Indicator       0
# dtype: int64

# %%
fig, ax = plt.subplots(3,3,figsize=(12,12))
fig.subplots_adjust(wspace=0.25, hspace=0.25)

ax[0][0].boxplot(df['Other Generation'])
ax[0][0].set_title('Other Generation ')

ax[0][1].boxplot(df['Germany Prices'])
ax[0][1].set_title('Germany Prices')

ax[0][2].boxplot(df['Total Grid'])
ax[0][2].set_title('Total Grid ')

ax[1][0].boxplot(df['Residual Load'])
ax[1][0].set_title('Residual Load')

ax[1][1].boxplot(df['Wind onshore'])
ax[1][1].set_title('Wind onshore')

ax[1][2].boxplot(df['Wind offshore'])
ax[1][2].set_title('Wind offshore')

ax[2][0].boxplot(df['Photovoltaics'])
ax[2][0].set_title('Photovoltaics')
# Out:
# Text(0.5, 1.0, 'Photovoltaics')

# %%
sns.distplot(df['Germany Prices'])
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_8904\1366053921.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Germany Prices'])
# C:\Users\asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Germany Prices', ylabel='Density'>

# %%
df.head()
# Out:
# 0                    Other Generation  Wind offshore  Wind onshore  \
# Start date
# 2020-01-01 00:00:00          34496.75         549.25       6085.00
# 2020-01-01 01:00:00          33937.75        1169.25       5886.75
# 2020-01-01 02:00:00          35350.00        1665.50       5771.50
# 2020-01-01 03:00:00          35671.50        2062.25       5487.50
# 2020-01-01 04:00:00          35358.00        2292.00       5458.50
#
# 0                    Photovoltaics  Germany Prices  Total Grid  Residual Load  \
# Start date
# 2020-01-01 00:00:00            0.0           41.88    43968.50       37334.25
# 2020-01-01 01:00:00            0.0           38.60    43047.00       35991.00
# 2020-01-01 02:00:00            0.0           36.55    41895.00       34458.00
# 2020-01-01 03:00:00            0.0           32.32    40701.75       33152.00
# 2020-01-01 04:00:00            0.0           30.85    40681.25       32930.75
#
# 0                    War Indicator
# Start date
# 2020-01-01 00:00:00            0.0
# 2020-01-01 01:00:00            0.0
# 2020-01-01 02:00:00            0.0
# 2020-01-01 03:00:00            0.0
# 2020-01-01 04:00:00            0.0

# %%
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import MinMaxScaler

# %%
features = df.drop(columns=['Germany Prices'])
target = df[['Germany Prices']]
features
# Out:
# 0                    Other Generation  Wind offshore  Wind onshore  \
# Start date
# 2020-01-01 00:00:00          34496.75         549.25       6085.00
# 2020-01-01 01:00:00          33937.75        1169.25       5886.75
# 2020-01-01 02:00:00          35350.00        1665.50       5771.50
# 2020-01-01 03:00:00          35671.50        2062.25       5487.50
# 2020-01-01 04:00:00          35358.00        2292.00       5458.50
# ...                               ...            ...           ...
# 2025-02-17 19:00:00          52226.75        1124.00       5165.25
# 2025-02-17 20:00:00          49565.00        1018.00       5401.50
# 2025-02-17 21:00:00          46741.50         966.25       5284.75
# 2025-02-17 22:00:00          44889.75         932.25       4965.00
# 2025-02-17 23:00:00          43025.25        1049.50       4717.00
#
# 0                    Photovoltaics  Total Grid  Residual Load  War Indicator
# Start date
# 2020-01-01 00:00:00            0.0    43968.50       37334.25            0.0
# 2020-01-01 01:00:00            0.0    43047.00       35991.00            0.0
# 2020-01-01 02:00:00            0.0    41895.00       34458.00            0.0
# 2020-01-01 03:00:00            0.0    40701.75       33152.00            0.0
# 2020-01-01 04:00:00            0.0    40681.25       32930.75            0.0
# ...                            ...         ...            ...            ...
# 2025-02-17 19:00:00            4.0    69697.25       63404.00            1.0
# 2025-02-17 20:00:00            0.0    66565.50       60146.00            1.0
# 2025-02-17 21:00:00            0.0    63781.25       57530.25            1.0
# 2025-02-17 22:00:00            0.0    61239.50       55342.25            1.0
# 2025-02-17 23:00:00            0.0    58464.25       52697.75            1.0
#
# [44995 rows x 7 columns]

# %%
scaler_features = MinMaxScaler()
scaler_target = MinMaxScaler()

# %%
features_normalised = scaler_features.fit_transform(features)
target_normalised = scaler_target.fit_transform(target)
target_normalised
# Out:
# array([[0.36465993],
#        [0.35523897],
#        [0.34935087],
#        ...,
#        [0.69011374],
#        [0.64473231],
#        [0.61652688]])

# %%
dt_arr_normalised = np.hstack((features_normalised, target_normalised))
dt_arr_normalised.shape
# Out:
# (44995, 8)

# %%
dt_arr_normalised[1]
# Out:
# array([0.42427783, 0.15014928, 0.15644842, 0.        , 0.23149742,
#        0.52227054, 0.        , 0.35523897])

# %%
target_column = 'Germany Prices'
target_index = df.columns.get_loc(target_column)
target_index
# Out:
# 4

# %%
def create_dataset(df,time_window):
    X,Y=[],[]
    for i in range(time_window, len(df)):
            X.append(df[i - time_window:i, 0:df.shape[1]])
            Y.append(df[i,-1])
    return np.array(X),np.array(Y)

# %%
train_size = int(0.75 * len(df))
df_train = df.iloc[:train_size]
df_test = df.iloc[train_size:]
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11249 entries, 2023-11-07 06:00:00 to 2025-02-17 23:00:00
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Other Generation  11249 non-null  float64
#  1   Wind offshore     11249 non-null  float64
#  2   Wind onshore      11249 non-null  float64
#  3   Photovoltaics     11249 non-null  float64
#  4   Germany Prices    11249 non-null  float64
#  5   Total Grid        11249 non-null  float64
#  6   Residual Load     11249 non-null  float64
#  7   War Indicator     11249 non-null  float64
# dtypes: float64(8)
# memory usage: 790.9 KB

# %%
# Splitting the data into train and test
dt_train, dt_test= dt_arr_normalised[0:round(0.75*len(dt_arr_normalised))] ,  dt_arr_normalised[round(0.75*len(dt_arr_normalised)):]   
dt_train.shape,dt_test.shape
# Out:
# ((33746, 8), (11249, 8))

# %%
time_window = 24
target_index = -1

# %%
dt_train
# Out:
# array([[0.43502866, 0.07053196, 0.16175958, ..., 0.54072799, 0.        ,
#         0.36465993],
#        [0.42427783, 0.15014928, 0.15644842, ..., 0.52227054, 0.        ,
#         0.35523897],
#        [0.45143857, 0.21387524, 0.15336084, ..., 0.50120576, 0.        ,
#         0.34935087],
#        ...,
#        [0.15796407, 0.57931234, 0.72976666, ..., 0.23856243, 1.        ,
#         0.43971163],
#        [0.16973421, 0.60274808, 0.70480483, ..., 0.26958592, 1.        ,
#         0.44614545],
#        [0.20678033, 0.58123856, 0.70128191, ..., 0.31690954, 1.        ,
#         0.48377183]])

# %%
X_train,Y_train=create_dataset(dt_train, time_window)
X_test, Y_test=create_dataset(dt_test,time_window)

# %%
X_train.shape,Y_train.shape,Y_train.shape,Y_test.shape
# Out:
# ((33722, 24, 8), (33722,), (33722,), (11225,))

# %%
import keras
from keras import layers
import tensorflow as tf
from keras.models import Sequential,Model
from tensorflow.keras.optimizers import Adam
from keras.layers import LSTM, Dense,Flatten
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error,mean_absolute_percentage_error

# %%
def lstm_attention_model(input_shape):
    inputs = keras.Input(shape=input_shape)
    
    lstm = layers.LSTM(100, return_sequences=True)(inputs)
    
    attention = layers.Dense(1, activation='tanh')(lstm)
    attention = layers.Flatten()(attention)
    attention = layers.Activation('softmax')(attention)
    attention = layers.RepeatVector(100)(attention)
    attention = layers.Permute([2, 1])(attention)
    attention = layers.Multiply()([lstm, attention])
    attention = layers.Lambda(lambda x: tf.reduce_sum(x, axis=1))(attention)
    
    outputs = layers.Dense(1)(attention)
    
    model = keras.Model(inputs=inputs, outputs=outputs)
    model.compile(loss='mse', optimizer='adam')
    model.summary()
    return model

# %%
model=lstm_attention_model(input_shape=(X_train.shape[1],X_train.shape[2]))
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 24, 8)]              0         []
#
#  lstm (LSTM)                 (None, 24, 100)              43600     ['input_1[0][0]']
#
#  dense (Dense)               (None, 24, 1)                101       ['lstm[0][0]']
#
#  flatten (Flatten)           (None, 24)                   0         ['dense[0][0]']
#
#  activation (Activation)     (None, 24)                   0         ['flatten[0][0]']
#
#  repeat_vector (RepeatVecto  (None, 100, 24)              0         ['activation[0][0]']
#  r)
#
#  permute (Permute)           (None, 24, 100)              0         ['repeat_vector[0][0]']
#
#  multiply (Multiply)         (None, 24, 100)              0         ['lstm[0][0]',
#                                                                      'permute[0][0]']
#
#  lambda (Lambda)             (None, 100)                  0         ['multiply[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    101       ['lambda[0][0]']
#
# ==================================================================================================
# Total params: 43802 (171.10 KB)
# Trainable params: 43802 (171.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model_loss = model.fit(X_train, Y_train, epochs=10,validation_split=0.2)
# Out:
# Epoch 1/10
# 844/844 [==============================] - 19s 18ms/step - loss: 0.0089 - val_loss: 0.0119
# Epoch 2/10
# 844/844 [==============================] - 15s 18ms/step - loss: 0.0036 - val_loss: 0.0029
# Epoch 3/10
# 844/844 [==============================] - 17s 20ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 4/10
# 844/844 [==============================] - 16s 19ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 5/10
# 844/844 [==============================] - 16s 18ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 6/10
# 844/844 [==============================] - 16s 19ms/step - loss: 0.0014 - val_loss: 0.0016
# Epoch 7/10
# 844/844 [==============================] - 17s 20ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 8/10
# 844/844 [==============================] - 16s 19ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 9/10
# 844/844 [==============================] - 16s 19ms/step - loss: 9.7880e-04 - val_loss: 0.0011
# Epoch 10/10
# 844/844 [==============================] - 16s 19ms/step - loss: 9.4661e-04 - val_loss: 0.0014

# %%
plt.plot(model_loss.history['loss'], label='Training Loss')
plt.plot(model_loss.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
Y_pred=model.predict(X_test)
# Out:
# 351/351 [==============================] - 3s 7ms/step

# %%
print ('R-Squared:',r2_score(Y_test,Y_pred))
print ('Mean squared error:', mean_squared_error (Y_pred, Y_test))
print('Mean absolute error',mean_absolute_error(Y_pred,Y_test))
print('Mean absolute percentage error',mean_absolute_percentage_error(Y_pred,Y_test))
# Out:
# R-Squared: 0.9175446626665426
# Mean squared error: 0.0014294945691922635
# Mean absolute error 0.0281853895764399
# Mean absolute percentage error 0.07150706409084749

# %%
plt.scatter(Y_pred, Y_test)

# %%
plt.figure(figsize=(20,6))

plt.plot(Y_test)
plt.plot(Y_pred)

plt.xlabel('Time',fontsize=16, fontweight='bold',fontfamily='serif')
plt.ylabel('Germany Prices',fontsize=16, fontweight='bold',fontfamily='serif')
plt.title('Observed vs Predicted ',fontsize=16, fontweight='bold',fontfamily='serif')
plt.legend(['Observed','Predicted'])

# %%
Y_pred_inverse = scaler_target.inverse_transform(Y_pred)
Y_test_inverse = scaler_target.inverse_transform(Y_test.reshape(-1, 1))

# %%
df_test.info()
Y_test_inverse.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 11249 entries, 2023-11-07 06:00:00 to 2025-02-17 23:00:00
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Other Generation  11249 non-null  float64
#  1   Wind offshore     11249 non-null  float64
#  2   Wind onshore      11249 non-null  float64
#  3   Photovoltaics     11249 non-null  float64
#  4   Germany Prices    11249 non-null  float64
#  5   Total Grid        11249 non-null  float64
#  6   Residual Load     11249 non-null  float64
#  7   War Indicator     11249 non-null  float64
# dtypes: float64(8)
# memory usage: 790.9 KB
# (11225, 1)

# %%
df_test = df.iloc[train_size+24:].copy()
df_test['Y_test_inverse'] = Y_test_inverse
df_test['Y_pred_inverse'] = Y_pred_inverse
df_test['Y_pred_inverse'].plot(figsize=(20,8))
df_test['Y_test_inverse'].plot(figsize=(20,8))
# Out:
# <Axes: xlabel='Start date'>

# %%
df_test['Y_pred_inverse'].tail(24).tolist()
# Out:
# [126.16847229003906,
#  121.75228881835938,
#  117.75670623779297,
#  118.68038177490234,
#  125.59953308105469,
#  131.77552795410156,
#  139.49758911132812,
#  166.72068786621094,
#  203.20005798339844,
#  188.3311767578125,
#  148.5801239013672,
#  130.17510986328125,
#  105.70256042480469,
#  100.70084381103516,
#  105.64231872558594,
#  117.09364318847656,
#  145.38099670410156,
#  183.91648864746094,
#  215.38104248046875,
#  193.80982971191406,
#  190.43341064453125,
#  162.4504852294922,
#  144.8439178466797,
#  132.1521759033203]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test.index, df_test['Y_test_inverse'], label='Actual Price (Y_test)', color='blue')
plt.plot(df_test.index, df_test['Y_pred_inverse'], label='Predicted Price (Y_pred)', color='orange')
plt.xlim([pd.to_datetime('2024-12-24 01:00:00'),pd.to_datetime('2024-12-29 23:00:00')])
plt.xlabel('Date')
plt.ylabel('Germany Prices')
plt.title('Germany Prices: Actual vs Predicted')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_test.index, df_test['Y_test_inverse'], label='Actual Price (Y_test)', color='blue')
plt.plot(df_test.index, df_test['Y_pred_inverse'], label='Predicted Price (Y_pred)', color='orange')
plt.xlim([pd.to_datetime('2025-02-17 01:00:00'),pd.to_datetime('2025-02-17 23:00:00')])
plt.xlabel('Date')
plt.ylabel('Germany Prices')
plt.title('Germany Prices: Actual vs Predicted')
plt.legend()
plt.show()

# %%
df_24_old = df.iloc[-24:,:]
df_24_old
# Out:
# 0                    Other Generation  Wind offshore  Wind onshore  \
# Start date
# 2025-02-17 00:00:00          36597.50         883.25       7221.00
# 2025-02-17 01:00:00          36326.75         615.25       6920.50
# 2025-02-17 02:00:00          36610.75         459.00       6327.00
# 2025-02-17 03:00:00          37020.75         309.00       5993.25
# 2025-02-17 04:00:00          38006.75         357.75       5763.00
# 2025-02-17 05:00:00          40703.25         494.75       5674.00
# 2025-02-17 06:00:00          44951.00         640.75       5804.50
# 2025-02-17 07:00:00          50024.00         689.50       5550.75
# 2025-02-17 08:00:00          50195.75         762.75       4784.00
# 2025-02-17 09:00:00          45463.50         795.75       2917.50
# 2025-02-17 10:00:00          41710.50         830.75       1669.75
# 2025-02-17 16:00:00            1.0
# 2025-02-17 17:00:00            1.0
# 2025-02-17 18:00:00            1.0
# 2025-02-17 19:00:00            1.0
# 2025-02-17 20:00:00            1.0
# 2025-02-17 21:00:00            1.0
# 2025-02-17 22:00:00            1.0
# 2025-02-17 23:00:00            1.0

# %%
df_24_future = pd.read_excel("forecasted/forecasted_day_data.xlsx")
df_24_future['Start date'] = pd.to_datetime(df_24_future['Start date'])
war_start_date = pd.Timestamp("2022-02-24")
df_24_future["War Indicator"] = (df_24_future["Start date"] >= war_start_date).astype(int)
df_24_future.set_index('Start date',inplace=True)
df_24_future.index = pd.to_datetime(df_24_future.index, errors='coerce')
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_20140\3749440001.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_24_future['Start date'] = pd.to_datetime(df_24_future['Start date'])

# %%
df_24_future['Germany Prices']=0
df_24_future
# Out:
#                      Total Grid  Residual Load  Wind offshore  Wind onshore  \
# Start date
# 2025-01-30 00:00:00    50947.25       27538.00        5323.25      18086.00
# 2025-01-30 01:00:00    49151.50       26861.50        5080.75      17209.25
# 2025-01-30 02:00:00    48425.50       27374.25        4809.25      16242.00
# 2025-01-30 03:00:00    48622.00       28862.25        4435.25      15324.50
# 2025-01-30 04:00:00    50107.00       31888.50        4056.75      14161.75
# 2025-01-30 05:00:00    53398.00       36950.00        3755.00      12693.00
# 2025-01-30 06:00:00    60117.75       45163.75        3581.00      11373.00
# 2025-01-30 07:00:00    65303.25       51839.50        3504.75       9931.00
# 2025-01-30 08:00:00    67515.50       53842.00        3325.50       8802.00
# 2025-01-30 09:00:00    68220.00       51822.00        3193.50       7752.25
# 2025-01-30 10:00:00    68890.75       49724.00        3080.75       6582.75
# 2025-01-30 11:00:00    69712.50       49102.50        2936.75       5473.00
# 2025-01-30 12:00:00    69542.75       49033.25        2826.25       4902.00
# 2025-01-30 13:00:00    68689.75       49720.00        2784.00       4824.75
# 2025-01-30 14:00:00    67013.25       50764.25        2782.25       4959.75
# 2025-01-30 15:00:00    66178.00       53417.00        2821.75       5260.75
# 2025-01-30 16:00:00    65843.25       55898.75        2869.50       5806.00
# 2025-01-30 17:00:00    67678.75       58300.00        2920.50       6432.50
# 2025-01-30 18:00:00    68412.75       58371.25        2984.75       7056.75
# 2025-01-30 19:00:00    66979.25       56029.75        3127.00       7822.50
# 2025-01-30 20:00:00    63764.75       51470.75        3344.00       8950.00
# 2025-01-30 21:00:00    60383.00       46896.00        3542.75       9944.25
# 2025-01-30 22:00:00    57267.75       42989.25        3704.25      10574.25
# 2025-01-30 23:00:00    53940.25       39161.25        3776.00      11003.00
#
#                      Photovoltaics  Other Generation  War Indicator  \
# Start date
# 2025-01-30 00:00:00           0.00          25472.75              1
# 2025-01-30 01:00:00           0.00          25086.00              1
# 2025-01-30 02:00:00           0.00          24888.75              1
# 2025-01-30 03:00:00           0.00          25085.25              1
# 2025-01-30 04:00:00           0.00          26030.50              1
# 2025-01-30 05:00:00           0.00          29589.00              1
# 2025-01-30 06:00:00           0.00          33538.00              1
# 2025-01-30 07:00:00          28.00          38492.25              1
# 2025-01-30 08:00:00        1546.00          40035.50              1
# 2025-01-29 21:00:00          32023.00        5636.25      21279.75
# 2025-01-29 22:00:00          31170.75        5350.75      19597.75
# 2025-01-29 23:00:00          29951.00        5209.25      18896.50
#
# 0                    Photovoltaics  Total Grid  Residual Load  War Indicator
# Start date
# 2025-01-29 00:00:00           0.00    50415.00       21267.00            1.0
# 2025-01-29 01:00:00           0.00    48874.25       20134.25            1.0
# 2025-01-29 02:00:00           0.00    48144.25       19775.00            1.0
# 2025-01-29 03:00:00           0.00    48434.00       19733.00            1.0
# 2025-01-29 04:00:00           0.00    49673.50       20496.00            1.0
# 2025-01-29 05:00:00           0.00    52859.75       23436.50            1.0
# 2025-01-29 06:00:00           0.00    59412.75       29030.50            1.0
# 2025-01-29 07:00:00          11.25    64927.50       34531.75            1.0
# 2025-01-29 08:00:00         847.50    67783.25       36223.00            1.0
# 2025-01-29 09:00:00        3663.50    69175.50       33270.25            1.0
# 2025-01-29 10:00:00        7585.75    70092.75       28211.75            1.0
# 2025-01-29 11:00:00       10895.25    71079.75       24270.25            1.0
# 2025-01-29 12:00:00       13284.00    70600.50       19567.00            1.0
# 2025-01-29 13:00:00       13628.00    69743.00       17522.75            1.0
# 2025-01-29 14:00:00       11452.75    68419.25       18810.75            1.0
# 2025-01-29 15:00:00        7050.00    67641.50       24270.50            1.0
# 2025-01-29 16:00:00        1752.00    66405.00       32695.25            1.0
# 2025-01-29 17:00:00          15.75    68445.00       39312.50            1.0
# 2025-01-29 18:00:00           0.00    68879.00       40817.50            1.0
# 2025-01-29 19:00:00           0.00    67702.75       40138.50            1.0
# 2025-01-29 20:00:00           0.00    64291.25       36632.25            1.0
# 2025-01-29 21:00:00           0.00    60962.75       34046.75            1.0
# 2025-01-29 22:00:00           0.00    57735.50       32787.00            1.0
# 2025-01-29 23:00:00           0.00    54069.50       29963.75            1.0

# %%
features_scaled=scaler_features.fit_transform(features_old)
target_scaled=scaler_target.fit_transform(target_old)

# %%
df_24_old_normalised=np.hstack((features_scaled,target_scaled))

# %%
features_future = df_24_future.drop(columns=['Germany Prices'])
target_future = df_24_future[['Germany Prices']]

# %%
feature_scaled_f=scaler_features.fit_transform(features_future)
# target_scaled_f=scaler_target.fit_transform(target_future)

# %%
df_24_future_normalised=np.hstack((feature_scaled_f,target_scaled))

# %%
df_24_future_normalised,df_24_old_normalised
# Out:
# (array([[1.18464321e-01, 2.14695451e-02, 1.00000000e+00, 1.00000000e+00,
#          0.00000000e+00, 3.40713515e-02, 0.00000000e+00, 1.62256548e-01],
#         [3.41053225e-02, 0.00000000e+00, 9.04565132e-01, 9.33886323e-01,
#          0.00000000e+00, 1.15078323e-02, 0.00000000e+00, 1.04096709e-01],
#         [0.00000000e+00, 1.62727410e-02, 7.97717434e-01, 8.60948251e-01,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3
 1.00000000e+00, 0.00000000e+00, 1.00000000e+00],
#         [8.36893636e-01, 9.23381117e-01, 2.31072906e-01, 0.00000000e+00,
#          8.52761004e-01, 9.70851801e-01, 0.00000000e+00, 9.49093351e-01],
#         [7.24841455e-01, 9.64299445e-01, 2.24817992e-01, 0.00000000e+00,
#          7.04017789e-01, 8.20335054e-01, 0.00000000e+00, 7.56346541e-01],
#         [6.01788496e-01, 1.00000000e+00, 1.62918276e-01, 0.00000000e+00,
#          5.58893418e-01, 7.09344380e-01, 0.00000000e+00, 5.91134990e-01],
#         [5.54378060e-01, 9.37276872e-01, 4.79372458e-02, 0.00000000e+00,
#          4.18183602e-01, 6.55265671e-01, 0.00000000e+00, 4.88247146e-01],
#         [4.86523698e-01, 9.06189927e-01, 0.00000000e+00, 0.00000000e+00,
#          2.58344052e-01, 5.34068835e-01, 0.00000000e+00, 3.18200134e-01]]))

# %%
future_scaled_df=pd.DataFrame(df_24_future_normalised)
future_scaled_df.iloc[:,-1]=np.nan

# %%
full_df=pd.concat([pd.DataFrame(df_24_old_normalised),future_scaled_df]).reset_index().drop(["index"],axis=1)

# %%
full_df_scaled_array=full_df.values
full_df_scaled_array.shape[1]
# Out:
# 8

# %%
full_df_scaled_array=full_df.values
all_data=[]
time_step=24
for i in range(time_step,len(full_df_scaled_array)):
    data_x=[]
    data_x.append(
    full_df_scaled_array[i-time_step :i , 0:full_df_scaled_array.shape[1]])
    data_x=np.array(data_x)
    prediction=model.predict(data_x)
    all_data.append(prediction)
    full_df.iloc[i,-1]=prediction
# Out:
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
new_array=np.array(all_data).reshape(-1,1)
# new_array=new_array.reshape(-1,1)
# prediction_copies_array = np.repeat(new_array,4, axis=-1)
y_pred_future_24 = scaler_target.inverse_transform(new_array).flatten()

# %%
df_24_future['Germany Prices'] = y_pred_future_24
df_24_future
# Out:
#                      Total Grid  Residual Load  Wind offshore  Wind onshore  \
# Start date
# 2025-01-30 00:00:00    50947.25       27538.00        5323.25      18086.00
# 2025-01-30 01:00:00    49151.50       26861.50        5080.75      17209.25
# 2025-01-30 02:00:00    48425.50       27374.25        4809.25      16242.00
# 2025-01-30 03:00:00    48622.00       28862.25        4435.25      15324.50
# 2025-01-30 04:00:00    50107.00       31888.50        4056.75      14161.75
# 2025-01-30 05:00:00    53398.00       36950.00        3755.00      12693.00
# 2025-01-30 06:00:00    60117.75       45163.75        3581.00      11373.00
# 2025-01-30 07:00:00    65303.25       51839.50        3504.75       9931.00
# 2025-01-30 08:00:00    67515.50       53842.00        3325.50       8802.00
# 2025-01-30 09:00:00    68220.00       51822.00        3193.50       7752.25
# 2025-01-30 10:00:00    68890.75       49724.00        3080.75       6582.75
# 2025-01-30 11:00:00    69712.50       49102.50        2936.75       5473.00
# 2025-01-30 12:00:00    69542.75       49033.25        2826.25       4902.00
